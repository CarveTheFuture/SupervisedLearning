# %% [markdown]
# <a href="https://colab.research.google.com/github/CarveTheFuture/SupervisedLearning/blob/master/Learning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats


np.random.seed(seed=123)

# %%
npts=1000
x_train=stats.uniform(-5,10).rvs(npts)

# %%
y_train=np.sin(x_train)+stats.norm(0,1).rvs(npts)

# %%
fig,ax=plt.subplots(figsize=(8,8))
ax.scatter(x_train,y_train,s=5)

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
keras=tf.keras
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.3.0
# 2.4.0

# %%
model=keras.models.Sequential()

# %%
model.add(keras.layers.Dense(units=1,input_dim=1))

# %%
model.compile(loss='mean_squared_error',optimizer='sgd')

# %%
model.fit(x_train,y_train,epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 0s 712us/step - loss: 3.6929
# Epoch 2/10
# 32/32 [==============================] - 0s 763us/step - loss: 1.4565
# Epoch 3/10
# 32/32 [==============================] - 0s 829us/step - loss: 1.4629
# Epoch 4/10
# 32/32 [==============================] - 0s 755us/step - loss: 1.4629
# Epoch 5/10
# 32/32 [==============================] - 0s 802us/step - loss: 1.4608
# Epoch 6/10
# 32/32 [==============================] - 0s 785us/step - loss: 1.4646
# Epoch 7/10
# 32/32 [==============================] - 0s 763us/step - loss: 1.4667
# Epoch 8/10
# 32/32 [==============================] - 0s 849us/step - loss: 1.4609
# Epoch 9/10
# 32/32 [==============================] - 0s 877us/step - loss: 1.4616
# Epoch 10/10
# 32/32 [==============================] - 0s 781us/step - loss: 1.4617

# %%
# !pip install
